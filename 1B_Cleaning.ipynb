# %%
import pandas as pd

# %%
df = pd.read_excel('data/table_1b_referrals_treatment__general_ccg_2014_15.xlsx')
df.head(15)
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0          NaN  Table 1b: Referrals received, entering treatme...        NaN
# 1          NaN                                                NaN        NaN
# 2          NaN                                            England        NaN
# 3          NaN                                                NaN        NaN
# 4          NaN                                                NaN        NaN
# 5          NaN                                                NaN        NaN
# 6          NaN                                                NaN        NaN
# 7          NaN                                      England total        NaN
# 8          NaN                                                NaN        NaN
# 9          NaN                                                NaN        00C
# 10         NaN                                                NaN        00D
# 11         NaN                                                NaN        00F
# 12         NaN                                                NaN        00G
# 13         NaN                                                NaN        00H
# 14         NaN                                                NaN        00J
#
#                                         Unnamed: 3             Unnamed: 4  \
# 0                                              NaN                    NaN
# 1                                              NaN                    NaN
# 2                                              NaN                    NaN
# 3                                              NaN                    NaN
# 4                                              NaN  Referrals received(2)
# 5                                              NaN                    NaN
# 6                                              NaN                    NaN
# 7                                              NaN                1267193
# 8                                              NaN                    NaN
# 9                               NHS Darlington CCG                   1925
# 10  NHS Durham Dales, Easington and Sedgefield CCG                   5120
# 11                               NHS Gateshead CCG                   5495
# 12                NHS Newcastle North and East CCG                   5140
# 13                          NHS Newcastle West CCG                   4125
# 14                            NHS North Durham CCG                   4550
#
#                          Unnamed: 5  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4   Referrals entering treatment(3)
# 5                               NaN
# 6                               NaN
# 7                            815665
# 8                               NaN
# 9                              1310
# 10                             3420
# 11                             4200
# 12                             3400
# 13                             2485
# 14                             3285
#
#                                       Unnamed: 6
# 0                                            NaN
# 1                                            NaN
# 2                                        numbers
# 3                                            NaN
# 4   Referrals finishing a course of treatment(4)
# 5                                            NaN
# 6                                            NaN
# 7                                         468881
# 8                                            NaN
# 9                                            885
# 10                                          2220
# 11                                          3150
# 12                                          1745
# 13                                          1210
# 14                                          1965

# %%
header_row = 5
df = pd.read_excel('data/table_1b_referrals_treatment__general_ccg_2014_15.xlsx',
    header=header_row
)

df.head(15)
# Out:
#     Unnamed: 0     Unnamed: 1 Unnamed: 2  \
# 0          NaN            NaN        NaN
# 1          NaN            NaN        NaN
# 2          NaN  England total        NaN
# 3          NaN            NaN        NaN
# 4          NaN            NaN        00C
# 5          NaN            NaN        00D
# 6          NaN            NaN        00F
# 7          NaN            NaN        00G
# 8          NaN            NaN        00H
# 9          NaN            NaN        00J
# 10         NaN            NaN        00K
# 11         NaN            NaN        00L
# 12         NaN            NaN        00M
# 13         NaN            NaN        00N
# 14         NaN            NaN        00P
#
#                                         Unnamed: 3 Referrals received(2)  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
# 2                                              NaN               1267193
# 3                                              NaN                   NaN
# 4                               NHS Darlington CCG                  1925
# 5   NHS Durham Dales, Easington and Sedgefield CCG                  5120
# 6                                NHS Gateshead CCG                  5495
# 7                 NHS Newcastle North and East CCG                  5140
# 8                           NHS Newcastle West CCG                  4125
# 9                             NHS North Durham CCG                  4550
# 10         NHS Hartlepool and Stockton-On-Tees CCG                  9260
# 11                          NHS Northumberland CCG                  8525
# 12                              NHS South Tees CCG                  8660
# 13                          NHS South Tyneside CCG                  4675
# 14                              NHS Sunderland CCG                  7295
#
#    Referrals entering treatment(3)  \
# 0                              NaN
# 1                              NaN
# 2                           815665
# 3                              NaN
# 4                             1310
# 5                             3420
# 6                             4200
# 7                             3400
# 8                             2485
# 9                             3285
# 10                            5605
# 11                            6410
# 12                            4650
# 13                            3655
# 14                            5615
#
#    Referrals finishing a course of treatment(4)
# 0                                           NaN
# 1                                           NaN
# 2                                        468881
# 3                                           NaN
# 4                                           885
# 5                                          2220
# 6                                          3150
# 7                                          1745
# 8                                          1210
# 9                                          1965
# 10                                         4005
# 11                                         4365
# 12                                         3460
# 13                                         2615
# 14                                         3625

# %%
# Drop rows that are completely empty
df = df.dropna(how="all")

# Drop columns that are completely empty
df = df.dropna(axis=1, how="all")

#Drop row 2
df = df.drop(index=2)

#Rename Unnamed: 3 to 'CCG Name'
df = df.rename(columns={df.columns[2]: 'CCG Name'})

#Merge Unnamed:1 and 2 together and rename to 'CCG Code'
df['CCG Code'] = df.iloc[:, 0].fillna('') + ' ' + df.iloc[:, 1].fillna('')
df = df.drop(df.columns[[0, 1]], axis=1)

df.head(15)
# Out:
#                                           CCG Name Referrals received(2)  \
# 4                               NHS Darlington CCG                  1925
# 5   NHS Durham Dales, Easington and Sedgefield CCG                  5120
# 6                                NHS Gateshead CCG                  5495
# 7                 NHS Newcastle North and East CCG                  5140
# 8                           NHS Newcastle West CCG                  4125
# 9                             NHS North Durham CCG                  4550
# 10         NHS Hartlepool and Stockton-On-Tees CCG                  9260
# 11                          NHS Northumberland CCG                  8525
# 12                              NHS South Tees CCG                  8660
# 13                          NHS South Tyneside CCG                  4675
# 14                              NHS Sunderland CCG                  7295
# 15                   NHS Blackburn with Darwen CCG                  4500
# 16                               NHS Blackpool CCG                  4570
# 17                                  NHS Bolton CCG                  8905
# 18                                    NHS Bury CCG                  6785
#
#    Referrals entering treatment(3)  \
# 4                             1310
# 5                             3420
# 6                             4200
# 7                             3400
# 8                             2485
# 9                             3285
# 10                            5605
# 11                            6410
# 12                            4650
# 13                            3655
# 14                            5615
# 15                            3305
# 16                            2340
# 17                            5690
# 18                            4220
#
#    Referrals finishing a course of treatment(4) CCG Code
# 4                                           885      00C
# 5                                          2220      00D
# 6                                          3150      00F
# 7                                          1745      00G
# 8                                          1210      00H
# 9                                          1965      00J
# 10                                         4005      00K
# 11                                         4365      00L
# 12                                         3460      00M
# 13                                         2615      00N
# 14                                         3625      00P
# 15                                         1555      00Q
# 16                                         1025      00R
# 17                                         3795      00T
# 18                                         2740      00V

# %%
df.head(250)
# Out:
#                                            CCG Name Referrals received(2)  \
# 4                                NHS Darlington CCG                  1925
# 5    NHS Durham Dales, Easington and Sedgefield CCG                  5120
# 6                                 NHS Gateshead CCG                  5495
# 7                  NHS Newcastle North and East CCG                  5140
# 8                            NHS Newcastle West CCG                  4125
# ..                                              ...                   ...
# 227                                             NaN                   NaN
# 229                                             NaN                   NaN
# 231                                             NaN                   NaN
# 233                                             NaN                   NaN
# 235                                             NaN                   NaN
#
#     Referrals entering treatment(3)  \
# 4                              1310
# 5                              3420
# 6                              4200
# 7                              3400
# 8                              2485
# ..                              ...
# 227                             NaN
# 229                             NaN
# 231                             NaN
# 233                             NaN
# 235                             NaN
#
#     Referrals finishing a course of treatment(4)  \
# 4                                            885
# 5                                           2220
# 6                                           3150
# 7                                           1745
# 8                                           1210
# ..                                           ...
# 227                                          NaN
# 229                                          NaN
# 231                                          NaN
# 233                                          NaN
# 235                                          NaN
#
#                                               CCG Code
# 4                                                  00C
# 5                                                  00D
# 6                                                  00F
# 7                                                  00G
# 8                                                  00H
# ..                                                 ...
# 227  (4)In order to finish a course of treatment, a...
# 229  All figures except England totals are rounded ...
# 231  Please note: Subtotals may not add to total du...
# 233  Numbers less than 5 (including 0) have been su...
# 235  Copyright © 2015, Health and Social Care Infor...
#
# [225 rows x 5 columns]

# %%
#Drop Lancashire Commissioning Hub and West Yorkshire Commissioning Hub rows
df = df[~df['CCG Name'].isin(['Lancashire Commissioning Hub', 'West Yorkshire Commissioning Hub'])]
df.head(250)
# Out:
#                                            CCG Name Referrals received(2)  \
# 4                                NHS Darlington CCG                  1925
# 5    NHS Durham Dales, Easington and Sedgefield CCG                  5120
# 6                                 NHS Gateshead CCG                  5495
# 7                  NHS Newcastle North and East CCG                  5140
# 8                            NHS Newcastle West CCG                  4125
# ..                                              ...                   ...
# 227                                             NaN                   NaN
# 229                                             NaN                   NaN
# 231                                             NaN                   NaN
# 233                                             NaN                   NaN
# 235                                             NaN                   NaN
#
#     Referrals entering treatment(3)  \
# 4                              1310
# 5                              3420
# 6                              4200
# 7                              3400
# 8                              2485
# ..                              ...
# 227                             NaN
# 229                             NaN
# 231                             NaN
# 233                             NaN
# 235                             NaN
#
#     Referrals finishing a course of treatment(4)  \
# 4                                            885
# 5                                           2220
# 6                                           3150
# 7                                           1745
# 8                                           1210
# ..                                           ...
# 227                                          NaN
# 229                                          NaN
# 231                                          NaN
# 233                                          NaN
# 235                                          NaN
#
#                                               CCG Code
# 4                                                  00C
# 5                                                  00D
# 6                                                  00F
# 7                                                  00G
# 8                                                  00H
# ..                                                 ...
# 227  (4)In order to finish a course of treatment, a...
# 229  All figures except England totals are rounded ...
# 231  Please note: Subtotals may not add to total du...
# 233  Numbers less than 5 (including 0) have been su...
# 235  Copyright © 2015, Health and Social Care Infor...
#
# [223 rows x 5 columns]

# %%
#Drop everything after the first occurrence of 'Data Source' in 'CCG Code' column
unknown_index = df[df['CCG Code'].str.contains('Data source', na=False)].index
if not unknown_index.empty:
    df = df.loc[:unknown_index[0]-1]

#Put 'UNK' in CCG Code for rows where CCG Name is 'Unknown CCG'
df.loc[df['CCG Name'] == 'Unknown CCG', 'CCG Code'] = 'UNK'
df.head(250)
# Out:
#                                            CCG Name Referrals received(2)  \
# 4                                NHS Darlington CCG                  1925
# 5    NHS Durham Dales, Easington and Sedgefield CCG                  5120
# 6                                 NHS Gateshead CCG                  5495
# 7                  NHS Newcastle North and East CCG                  5140
# 8                            NHS Newcastle West CCG                  4125
# ..                                              ...                   ...
# 215        NHS North East Hampshire and Farnham CCG                  4360
# 216                               NHS Wiltshire CCG                 11330
# 217     NHS Northern, Eastern and Western Devon CCG                 16615
# 218                  NHS South Devon and Torbay CCG                  6170
# 220                                     Unknown CCG                  1600
#
#     Referrals entering treatment(3)  \
# 4                              1310
# 5                              3420
# 6                              4200
# 7                              3400
# 8                              2485
# ..                              ...
# 215                            2590
# 216                           11195
# 217                           12130
# 218                            4685
# 220                             845
#
#     Referrals finishing a course of treatment(4) CCG Code
# 4                                            885      00C
# 5                                           2220      00D
# 6                                           3150      00F
# 7                                           1745      00G
# 8                                           1210      00H
# ..                                           ...      ...
# 215                                         1785      99M
# 216                                         5455      99N
# 217                                         8105      99P
# 218                                         2820      99Q
# 220                                          930      UNK
#
# [214 rows x 5 columns]

# %%
#Save cleaned dataframe to new excel file
df.to_excel('cleaned_data/cleaned_table_1b.xlsx', index=False)
