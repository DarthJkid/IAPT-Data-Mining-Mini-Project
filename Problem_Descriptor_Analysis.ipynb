# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (9, 5)
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["axes.labelsize"] = 11

# %%
# Fixed paths
df_2c  = pd.read_excel("cleaned_data/cleaned_table_2c.xlsx")
df_3   = pd.read_excel("cleaned_data/cleaned_table_3.xlsx")
df_4   = pd.read_excel("cleaned_data/cleaned_table_4.xlsx")
df_5a  = pd.read_excel("cleaned_data/cleaned_table_5a.xlsx")
df_5b  = pd.read_excel("cleaned_data/cleaned_table_5b.xlsx")
df_6   = pd.read_excel("cleaned_data/cleaned_table_6.xlsx")
df_7   = pd.read_excel("cleaned_data/cleaned_table_7.xlsx")
df_9d  = pd.read_excel("cleaned_data/cleaned_table_9d.xlsx")
df_15  = pd.read_excel("cleaned_data/cleaned_table_15.xlsx")  # employment status

print("2c:", df_2c.shape)
print("3 :", df_3.shape)
print("4 :", df_4.shape)
print("5a:", df_5a.shape)
print("5b:", df_5b.shape)
print("6 :", df_6.shape)
print("7 :", df_7.shape)
print("9d:", df_9d.shape)
print("15:", df_15.shape)

display(df_2c.head())
display(df_9d.head())
display(df_15.head())
