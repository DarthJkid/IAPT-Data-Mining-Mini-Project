# %%
import pandas as pd

# %%
df = pd.read_excel('data/table_2b_referrals_entering_treatment_ccg_waiting_time_2014_15.xlsx')
df.head(250)
# Out:
#     CCG Code                                        CCG Name  \
# 0        00C                              NHS Darlington CCG
# 1        00D  NHS Durham Dales, Easington and Sedgefield CCG
# 2        00F                               NHS Gateshead CCG
# 3        00G                NHS Newcastle North and East CCG
# 4        00H                          NHS Newcastle West CCG
# ..       ...                                             ...
# 209      99M        NHS North East Hampshire and Farnham CCG
# 210      99N                               NHS Wiltshire CCG
# 211      99P     NHS Northern, Eastern and Western Devon CCG
# 212      99Q                  NHS South Devon and Torbay CCG
# 213      UNK                                     Unknown CCG
#
#      Total Referrals to Treatment  <28 days  29-56 days 57-90 days >90 days  \
# 0                            1310      1210          75         25        *
# 1                            3420      3115         240         45       20
# ...

# %%
df.to_excel('cleaned_data/cleaned_table_2b.xlsx', index=False)
